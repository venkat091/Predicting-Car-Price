# %% [markdown]
# Step1: Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Step2: Importing data

# %%
prices_df = pd.read_csv('automobile.csv', header = None, names = ['symboling','normalized_losses','make','fuel_type','aspiration','num_of_doors','bodystyle','drive_wheels','engine_location','wheel_base','length','width','height','curb_weight','engine_type','num_of_cylinders','engine_size','fuel_system','bore','stroke','compression_ratio','horsepower','peak_rpm','city_mpg','highway_mpg','price'], na_values = '?')

# %% [markdown]
# Step3: Feature Engineering

# %%
prices_df[prices_df.columns[prices_df.isnull().any()]].isnull().sum()
# Out:
# normalized_losses    41
# num_of_doors          2
# bore                  4
# stroke                4
# horsepower            2
# peak_rpm              2
# price                 4
# dtype: int64

# %% [markdown]
# ---- Dropping rows where price (target variable) does not exists

# %%
prices_df.dropna(subset =['price'], inplace = True, axis=0)

# %%
prices_df[prices_df.columns[prices_df.isnull().any()]].isnull().sum()
# Out:
# normalized_losses    37
# num_of_doors          2
# bore                  4
# stroke                4
# horsepower            2
# peak_rpm              2
# dtype: int64

# %% [markdown]
# --- Dropping normalized_losses because 20% of data is missing
# --- Dropping make feature, it does not make sense to consider for small set of data which contains variety of cara make
# --- Dropping Symboling, its for pictorial representation of safety of a car. It does not have arole in deciding price

# %%
prices_df.drop(['symboling', 'normalized_losses','make'], inplace = True, axis = 1)

# %%
prices_df
# Out:
#     fuel_type aspiration num_of_doors    bodystyle drive_wheels  \
# 0         gas        std          two  convertible          rwd
# 1         gas        std          two  convertible          rwd
# 2         gas        std          two    hatchback          rwd
# 3         gas        std         four        sedan          fwd
# 4         gas        std         four        sedan          4wd
# ..        ...        ...          ...          ...          ...
# 200       gas        std         four        sedan          rwd
# 201       gas      turbo         four        sedan          rwd
# 202       gas        std         four        sedan          rwd
# 203    diesel      turbo         four        sedan          rwd
# 204       gas      turbo         four        sedan          rwd
#
#     engine_location  wheel_base  length  width  height  ...  engine_size  \
# 0             front        88.6   168.8   64.1    48.8  ...          130
# 1             front        88.6   168.8   64.1    48.8  ...          130
# 2             front        94.5   171.2   65.5    52.4  ...          152
# 3             front        99.8   176.6   66.2    54.3  ...          109
# 4             front        99.4   176.6   66.4    54.3  ...          136
# ..              ...         ...     ...    ...     ...  ...          ...
# 200           front       109.1   188.8   68.9    55.5  ...          141
# 201           front       109.1   188.8   68.8    55.5  ...          141
# 202           front       109.1   188.8   68.9    55.5  ...          173
# 203           front       109.1   188.8   68.9    55.5  ...          145
# 204           front       109.1   188.8   68.9    55.5  ...          141
#
#     fuel_system  bore  stroke compression_ratio  horsepower  peak_rpm  \
# 0          mpfi  3.47    2.68               9.0       111.0    5000.0
# 1          mpfi  3.47    2.68               9.0       111.0    5000.0
# 2          mpfi  2.68    3.47               9.0       154.0    5000.0
# 3          mpfi  3.19    3.40              10.0       102.0    5500.0
# 4          mpfi  3.19    3.40               8.0       115.0    5500.0
# ..          ...   ...     ...               ...         ...       ...
# 200        mpfi  3.78    3.15               9.5       114.0    5400.0
# 201        mpfi  3.78    3.15               8.7       160.0    5300.0
# 202        mpfi  3.58    2.87               8.8       134.0    5500.0
# 203         idi  3.01    3.40              23.0       106.0    4800.0
# 204        mpfi  3.78    3.15               9.5       114.0    5400.0
#
#      city_mpg  highway_mpg    price
# 0          21           27  13495.0
# 1          21           27  16500.0
# 2          19           26  16500.0
# 3          24           30  13950.0
# 4          18           22  17450.0
# ..        ...          ...      ...
# 200        23           28  16845.0
# 201        19           25  19045.0
# 202        18           23  21485.0
# 203        26           27  22470.0
# 204        19           25  22625.0
#
# [201 rows x 23 columns]

# %% [markdown]
# Step4: Identifying Input & Target Variables

# %%
Input_cols = prices_df.iloc[:,:-1]
Target_col = prices_df.iloc[:,-1]

# %% [markdown]
# --- Forming Numerical & Categorical Columns

# %%
numeric_cols = prices_df.select_dtypes(include = np.number).columns[:-1].tolist()
categorical_cols = prices_df.select_dtypes(include = 'object').columns.tolist()

# %% [markdown]
# Step5: Imputing missing values

# %% [markdown]
# --- Replacing missing values with average of that features, bore, stroke, horsepower, peak_rpm

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy = 'mean')
imputer.fit(Input_cols[numeric_cols])
Input_cols[numeric_cols] = imputer.transform(Input_cols[numeric_cols])

# %%
Input_cols[Input_cols.num_of_doors.isnull()]
# Out:
#    fuel_type aspiration num_of_doors bodystyle drive_wheels engine_location  \
# 27       gas      turbo          NaN     sedan          fwd           front
# 63    diesel        std          NaN     sedan          fwd           front
#
#     wheel_base  length  width  height  ...  num_of_cylinders engine_size  \
# 27        93.7   157.3   63.8    50.6  ...              four        98.0
# 63        98.8   177.8   66.5    55.5  ...              four       122.0
#
#    fuel_system  bore stroke  compression_ratio  horsepower  peak_rpm  \
# 27        mpfi  3.03   3.39                7.6       102.0    5500.0
# 63         idi  3.39   3.39               22.7        64.0    4650.0
#
#     city_mpg  highway_mpg
# 27      24.0         30.0
# 63      36.0         42.0
#
# [2 rows x 22 columns]

# %%
prices_df.corr()
# Out:
#                    wheel_base    length     width    height  curb_weight  \
# wheel_base           1.000000  0.876024  0.814507  0.590742     0.782097
# length               0.876024  1.000000  0.857170  0.492063     0.880665
# width                0.814507  0.857170  1.000000  0.306002     0.866201
# height               0.590742  0.492063  0.306002  1.000000     0.307581
# curb_weight          0.782097  0.880665  0.866201  0.307581     1.000000
# engine_size          0.572027  0.685025  0.729436  0.074694     0.849072
# bore                 0.494884  0.610051  0.544924  0.185907     0.644617
# stroke               0.158502  0.124139  0.188829 -0.062704     0.167562
# compression_ratio    0.250313  0.159733  0.189867  0.259737     0.156433
# horsepower           0.371621  0.580309  0.615315 -0.087407     0.758063
# peak_rpm            -0.360593 -0.286321 -0.245975 -0.311574    -0.279375
# city_mpg            -0.470606 -0.665192 -0.633531 -0.049800    -0.749543
# highway_mpg         -0.543304 -0.698142 -0.680635 -0.104812    -0.794889
# price                0.584642  0.690628  0.751265  0.135486     0.834415
#
#                    engine_size      bore    stroke  compression_ratio  \
# wheel_base            0.572027  0.494884  0.158502           0.250313
# length                0.685025  0.610051  0.124139           0.159733
# width                 0.729436  0.544924  0.188829           0.189867
# height                0.074694  0.185907 -0.062704           0.259737
# curb_weight           0.849072  0.644617  0.167562           0.156433
# engine_size           1.000000  0.582857  0.209523           0.028889
# bore                  0.582857  1.000000 -0.055390           0.001250
# stroke                0.209523 -0.055390  1.000000           0.187923
# compression_ratio     0.028889  0.001250  0.187923           1.000000
# horsepower            0.822713  0.568527  0.100040          -0.214576
# peak_rpm             -0.256773 -0.277662 -0.068300          -0.436015
# city_mpg             -0.650546 -0.592655 -0.034696           0.331425
# highway_mpg          -0.679571 -0.599218 -0.035201           0.268465
# price                 0.872335  0.543436  0.082310           0.071107
#
#                    horsepower  peak_rpm  city_mpg  highway_mpg     price
# wheel_base           0.371621 -0.360593 -0.470606    -0.543304  0.584642
# length               0.580309 -0.286321 -0.665192    -0.698142  0.690628
# width                0.615315 -0.245975 -0.633531    -0.680635  0.751265
# height              -0.087407 -0.311574 -0.049800    -0.104812  0.135486
# curb_weight          0.758063 -0.279375 -0.749543    -0.794889  0.834415
# engine_size          0.822713 -0.256773 -0.650546    -0.679571  0.872335
# bore                 0.568527 -0.277662 -0.592655    -0.599218  0.543436
# stroke               0.100040 -0.068300 -0.034696    -0.035201  0.082310
# compression_ratio   -0.214576 -0.436015  0.331425     0.268465  0.071107
# horsepower           1.000000  0.107882 -0.822617    -0.804596  0.810533
# peak_rpm             0.107882  1.000000 -0.115425    -0.058606 -0.101649
# city_mpg            -0.822617 -0.115425  1.000000     0.972044 -0.686571
# highway_mpg         -0.804596 -0.058606  0.972044     1.000000 -0.704692
# price                0.810533 -0.101649 -0.686571    -0.704692  1.000000

# %% [markdown]
# Encoding Categorical Varaiables

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse=False, handle_unknown='ignore').fit(Input_cols[categorical_cols])
encoded_cols = list(encoder.get_feature_names(categorical_cols))
Input_cols[encoded_cols] = encoder.transform(Input_cols[categorical_cols])

# %%
Inputs = Input_cols[numeric_cols + encoded_cols].copy()
target = prices_df['price']
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 201, dtype: float64

# %% [markdown]
# Splitting data to training & test set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(Inputs, target, test_size = 0.2, random_state = 0)

# %%
train_inputs = x_train[numeric_cols + encoded_cols].copy()
test_inputs  = x_test[numeric_cols + encoded_cols].copy()
train_targets = y_train.copy()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
train_inputs[numeric_cols] = scaler.fit_transform(train_inputs[numeric_cols])
test_inputs[numeric_cols] = scaler.transform(test_inputs[numeric_cols])

# %%
train_inputs.describe().loc[['min', 'max']]
# Out:
#      wheel_base    length     width    height  curb_weight  engine_size  \
# min   -2.042542 -2.731825 -2.607875 -2.394867    -2.059335    -1.578442
# max    3.767883  2.846833  2.893525  2.508252     2.767993     4.869764
#
#          bore    stroke  compression_ratio  horsepower  ...  \
# min -2.481807 -3.563465          -0.809902   -1.514523  ...
# max  1.767077  2.174294           3.611640    4.390565  ...
#
#      num_of_cylinders_twelve  num_of_cylinders_two  fuel_system_1bbl  \
# min                      0.0                   0.0               0.0
# max                      1.0                   1.0               1.0
#
#      fuel_system_2bbl  fuel_system_4bbl  fuel_system_idi  fuel_system_mfi  \
# min               0.0               0.0              0.0              0.0
# max               1.0               1.0              1.0              1.0
#
#      fuel_system_mpfi  fuel_system_spdi  fuel_system_spfi
# min               0.0               0.0               0.0
# max               1.0               1.0               1.0
#
# [2 rows x 51 columns]

# %% [markdown]
# Training Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(train_inputs, train_targets)
# Out:
# LinearRegression()

# %%
train_pred = regressor.predict(train_inputs)
test_pred = regressor.predict(test_inputs)

# %% [markdown]
# RMSE & R2 Values

# %%
from sklearn.metrics import mean_squared_error, r2_score
train_rmse = mean_squared_error(train_targets, train_pred, squared = False)
test_rmse = mean_squared_error(y_test, regressor.predict(test_inputs), squared = False)
train_r2 = r2_score(train_targets, train_pred)
test_r2 = r2_score(y_test, regressor.predict(test_inputs))
print("train_rmse: ", train_rmse)
print("test_rmse: ", test_rmse)
print("train_r2: ", train_r2)
print("test_r2: ", test_r2)
# Out:
# train_rmse:  1931.2162103115368
# train_rmse:  2839.4283130347726
# train_r2:  0.9369143086254367
# test_r2:  0.893594798870135

# %%
residual_train = train_targets - train_pred

# %% [markdown]
# ## Applying k-Fold Cross Validation

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = regressor, X = train_inputs, y = train_targets, cv = 3)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracy: 79.10 %
# Standard Deviation: 4.59 %

# %% [markdown]
# # Training Ridge Regression

# %%
from sklearn.linear_model import Ridge
regressor_R = Ridge()
regressor_R.fit(train_inputs, train_targets)
# Out:
# Ridge()

# %%
train_pred_R = regressor_R.predict(train_inputs)
test_pred_R = regressor_R.predict(test_inputs)

# %%
from sklearn.metrics import mean_squared_error, r2_score
train_rmse = mean_squared_error(train_targets, train_pred_R, squared = False)
test_rmse = mean_squared_error(y_test, regressor_R.predict(test_inputs), squared = False)
train_r2 = r2_score(train_targets, train_pred_R)
test_r2 = r2_score(y_test, regressor_R.predict(test_inputs))
print("train_rmse: ", train_rmse)
print("test_rmse: ", test_rmse)
print("train_r2: ", train_r2)
print("test_r2: ", test_r2)
# Out:
# train_rmse:  2044.8531836240368
# test_rmse:  2635.8854561513617
# train_r2:  0.9292716812775341
# test_r2:  0.9083032153164604

# %% [markdown]
# ## Applying k-Fold Cross Validation

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = regressor_R, X = train_inputs, y = train_targets, cv = 3)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracy: 84.73 %
# Standard Deviation: 1.18 %
